# %% [markdown]
# <a href="https://colab.research.google.com/github/Swetankan/IBM-SkillsBuild-Edunet-Capstone-project/blob/main/Heart_Disease_prediction(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###1.) Importing the libraries and dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("heart_ds.csv")

# %% [markdown]
# ###2.) Display top 5 Rows of the dataset using head function

# %%
dataset.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# **Attribute Information:**
# 1.  age
# 2.  sex
# 3.  chest pain type (4 values)
#      *   Value 0: typical agina
#      *   Value 1: atypical agina
#      *   Value 2: non-aginal pain
#      *   Value 3: asymptomatic
# 4.  trestbps: resting blood pressure (in mm Hg)
# 5.  chol: serum cholestoral in mg/dl
# 6.  fbs: fasting blood sugar > 120 mg/dl(1=true, 0=false)
# 7.  restecg: resting electrocardiographic results (values 0,1,2)
#      *   Value 0: normal
#      *   Value 1: having ST-T wave abnormality
#      *   Value 2: showing probable or definite left ventricular hypertrophy by Estes's criteria
#
# 8.  thalach: maximum heart rate achieved
# 9.  exang: exercise induced angina(1:yes; 0=no)
# 10. oldpeak = ST depression induced by exercise relative to rest
# 11. slope: the slope of the peak exercise ST segment
#      *   Value 1: upsloping
#      *   Value 2: flat
#      *   Value 3: downsloping
# 12. ca: number of major vessels (0-3) colored by flourosopy
# 13. thal: 0 = normal; 1 = fixed defect; 2 = reversable defect
# 14. target: 0=less chance of heart attack, 1=more chance of heart attack
#
# The names and social security numbers of the patients were recently removed from the database, replaced with dummy values.

# %% [markdown]
# ###3.) Display the last 5 rows of the dataset using tail function

# %%
dataset.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# ### 4.) Finding shape of dataset

# %%
print(f"There are {dataset.shape[0]} rows and {dataset.shape[1]} columns in this dataset")
# Out:
# There are 1025 rows and 14 columns in this dataset

# %% [markdown]
# ###**5.) Getting information about dataset using info function**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# ###**6.) Check for Null Valuse is the dataset**

# %%
dataset.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ###**7.) Check for duplicate data and delete them**

# %%
duplicate_data=dataset.duplicated()
duplicate_data
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1020     True
# 1021     True
# 1022     True
# 1023     True
# 1024     True
# Length: 1025, dtype: bool

# %%
dataset=dataset.drop_duplicates()

# %%
dataset.shape
# Out:
# (302, 14)

# %% [markdown]
# ###**8.) Get overall stastics about dataset using describe fun**

# %%
dataset.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# ###**9.) Draw correlation matrix using corr() and visualize it using heatmap method**

# %%
plt.figure(figsize=(19,5))
sns.heatmap(dataset.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ###**10.) Check how many person have heart disease and hom many have not in this dataset using value_counts() & Visualisng it using seaborn**

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
x=dataset["target"].value_counts()
x
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
palette = sns.color_palette(["green", "red"])
sns.countplot(x='target',data=dataset, hue="target",palette=palette)
plt.xticks([0,1],['Less chance of heart attack', 'More chance of heart attack'])
plt.show()

# %% [markdown]
# ###11.) Which Sex Has The Most Heart Disease [ Male or Female ]?

# %%
dataset['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
sns.countplot(x='sex',data=dataset,hue='sex')
plt.xticks([0,1],['Female', 'Male'])
plt.show()

# %% [markdown]
# ### 12.) Find Gender Distribution According to The Target Variable.

# %%
sns.countplot(x='sex',hue='target',data=dataset)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# ###13.) Visualise age distribution by using distplot()**

# %%
sns.distplot(dataset['age'],bins=20)
plt.show()
# Out:
# <ipython-input-128-fd431ca1ed05>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['age'],bins=20)

# %% [markdown]
# ### 14.) Check Chest Pain Type
# - chest pain type (4 values)
#  - Value 0: typical angina
#  - Value 1: atypical angina
#  - Value 2: non-anginal pain
#  - Value 3: asymptomatic

# %%
sns.countplot(x='cp',data=dataset, hue='cp', palette='bright')
plt.xticks([0,1,2,3],["typical angina","atypical angina","non-anginal pain","asymptomatic "])
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# ### 15.) Show The Chest Pain Distribution As Per Target Variable

# %%
sns.countplot(x='cp',hue='target',data=dataset,palette=palette)
plt.legend(labels=['No-Disease','Diseases'])
plt.show()

# %% [markdown]
# ### 16.) Show Fasting Blood Sugar Distribution According To Target Variable

# %%
sns.countplot(x='fbs',hue='target',data=dataset,palette=palette)
plt.legend(labels=['No-Disease','Diseases'])
plt.show()

# %% [markdown]
# ### 17.) Compare Resting Blood Pressure As Per Sex Column

# %%
g = sns.FacetGrid(dataset,hue='sex',aspect=6)
g.map(sns.kdeplot,'trestbps',fill=True)
plt.legend(labels=['Male','Female'])
plt.show()

# %% [markdown]
# ### 18.) Show Distribution of Serum cholesterol

# %%
dataset['chol'].hist(color='g')
plt.show()

# %% [markdown]
# ### 19.) Plot Continuous Variables

# %%
cate_val = []
cont_val = []
for column in dataset.columns:
    if len(dataset[column].unique())<=10:
        cate_val.append(column)
    else:
        cont_val.append(column)

# %%
cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
dataset.hist(cont_val,figsize=(15,6),color='g')
plt.tight_layout()
plt.show()
